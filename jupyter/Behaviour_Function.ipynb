# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

critical_fee = 3
constructive_fee = 7

# %%
# Token-based incentive

plt.figure(figsize=(5, 5))

# x is the paper quality score, ranging from [0, 1]
x = np.linspace(0, 1, 1000)

theta = 0.8
# the expected token reward
reward = -0.5 * (critical_fee + constructive_fee) * np.tanh(8 * (x - theta)) + 0.5 * (critical_fee - constructive_fee)
y = -0.5 * np.tanh(8 * (x - theta)) + 0.5 * (critical_fee - constructive_fee) / (critical_fee + constructive_fee)

plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.xlabel('paper quality score', fontsize=12)
plt.ylabel('f(x) - token incentive', fontsize=12)
plt.grid()
plt.plot(x, y)
plt.axhline(y=p_fee, color = 'r', linestyle = '--')
plt.axhline(y=n_fee, color = 'r', linestyle = '--')
plt.show()

# %%
# Reputation-based incentive

plt.figure(figsize=(5, 5))

# x is the paper quality score, ranging from [0, 1]

x = np.linspace(-10, 10, 1000)

# assumption - scholars tend to review paper with higher quality
y = x**2
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('paper quality score', fontsize=12)
plt.ylabel('g(x) - reputation incentive', fontsize=12)
plt.grid()
plt.plot(x, y)
plt.show()
